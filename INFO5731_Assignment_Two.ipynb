# %% [markdown]
# <a href="https://colab.research.google.com/github/DurgaBhavana/5731Submissions/blob/master/INFO5731_Assignment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [2019 Dell labtop](https://www.amazon.com/Dell-Inspiron-5000-5570-Laptop/dp/B07N49F51N/ref=sr_1_11?crid=1IJ7UWF2F4GHH&keywords=dell%2Bxps%2B15&qid=1580173569&sprefix=dell%2Caps%2C181&sr=8-11&th=1) on amazon.
#
# (2) Collect the top 100 User Reviews of the film [Joker](https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv) from IMDB.
#
# (3) Collect the abstracts of the top 100 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (4) Collect the top 100 tweets by using hashtag ["#CovidVaccine"](https://twitter.com/hashtag/CovidVaccine) from Twitter.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
abstract_text = []
count = 0
for i in range(10):
  link = 'https://citeseerx.ist.psu.edu/search;jsessionid=87FF6C66EA09F22314C131669600CF98?q=natural+language+processing&t=doc&sort=rlv&start='
  page = requests.get(link + str (count))
  abstract = (BeautifulSoup(page.text, 'html.parser')).find_all(class_='pubabstract')
  count = count + 10
  for i in abstract:
    abstract_text.append(i.text.replace('\n', '').strip())

# %%
df = pd.DataFrame((abstract_text), columns =['Abstract'])
df.to_csv('abstracts.csv')
df
# Out:
#                                              Abstract
# 0                                  Abstract not found
# 1   describe a method for statistical modeling bas...
# 2   Scaling conditional random fields for natural ...
# 3   The paper addresses the issue of cooperation b...
# 4   In most natural language processing applicatio...
# ..                                                ...
# 95  This paper presents a workbench built by Pribe...
# 96  Abstract—Natural Language Processing (NLP) is ...
# 97  ABSTRACT: After twenty years of disfavor, a te...
# 98  Text statistics are frequently used in stylome...
# 99  We summarize our experience using FrameNet in ...
#
# [100 rows x 1 columns]

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
import re
from nltk.stem import PorterStemmer
from textblob import TextBlob
from textblob import Word
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# Special characters removal
df['After noise removal'] = df['Abstract'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))
# Punctuation removal
df['Punctuation removal'] = df['After noise removal'].str.replace('[^\w\s]','')
# Remove numbers
df['Remove numbers'] = df['Punctuation removal'].str.replace('\d+', '')
# Stopwords removal
stop_word = stopwords.words('english')
df['Stopwords removal'] = df['Remove numbers'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_word))
# Lower Casing
df['Lower casing'] = df['Stopwords removal'].apply(lambda x: " ".join(x.lower() for x in x.split()))
# Stemming
st = PorterStemmer()
df['Stemming'] = df['Lower casing'].apply(lambda x: " ".join([st.stem(word) for word in x]))
# Lemmatization
df['Lemmatization'] = df['Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
import spacy
nltk.download('punkt')
from spacy import displacy
from nltk import word_tokenize, pos_tag, pos_tag_sents
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# POS Tagging
from collections import Counter
parts_of_speech = []
iterns = []
texts = df['Stopwords removal'].tolist()
for iter in texts:
  parts_of_speech.append(nltk.pos_tag(word_tokenize(iter)))
print(parts_of_speech)
for iter in parts_of_speech:
  iterns.append(Counter(tag for word, tag in iter))
print(iterns)
# Out:
# [[('Abstract', 'NNP'), ('found', 'VBD')], [('describe', 'NN'), ('method', 'NN'), ('statistical', 'JJ'), ('modeling', 'NN'), ('based', 'VBN'), ('maximum', 'JJ'), ('entropy', 'NN'), ('We', 'PRP'), ('present', 'JJ'), ('maximum', 'JJ'), ('likelihood', 'NN'), ('approach', 'NN'), ('automatically', 'RB'), ('constructing', 'VBG'), ('maximum', 'JJ'), ('entropy', 'JJ'), ('models', 'NNS'), ('describe', 'VBP'), ('implement', 'JJ'), ('approach', 'NN'), ('efficiently', 'RB'), ('using', 'VBG'), ('examples', 'NNS'), ('several', 'JJ'), ('problems', 'NNS'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN')], [('Scaling', 'VBG'), ('conditional', 'JJ'), ('random', 'NN'), ('fields', 'NNS'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('Terms', 'NNS'), ('Conditions', 'NNPS'), ('Terms', 'NNS'), ('Conditions', 'NNPS'), ('Copyright', 'NNP'), ('works', 'NNS'), ('deposited', 'VBD'), ('Minerva', 'NNP'), ('Access', 'NNP'), ('retained', 'VBD')], [('The', 'DT'), ('paper', 'NN'), ('addresses', 'VBZ'), ('issue', 'JJ'), ('cooperation', 'NN'), ('linguistics', 'NNS'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('NLP', 'NNP'), ('general', 'JJ'), ('linguistics', 'NNS'), ('machine', 'NN'), ('translation', 'NN'), ('MT', 'NNP'), ('particular', 'VBZ'), ('It', 'PRP'), ('focuses', 'VBZ'), ('one', 'CD'), ('direction', 'NN'), ('cooperation', 'NN'), ('namely', 'RB'), ('applications', 'NNS'), ('linguistics', 'NNS'), ('NLP', 'NNP'), ('virtually', 'RB')], [('In', 'IN'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('applications', 'NNS'), ('Description', 'NNP'), ('Logics', 'NNP'), ('used', 'VBD'), ('encode', 'NN'), ('knowledge', 'NN'), ('base', 'NN'), ('syntactic', 'JJ'), ('semantic', 'JJ'), ('pragmatic', 'JJ'), ('elements', 'NNS'), ('needed', 'VBN'), ('drive', 'JJ'), ('semantic', 'JJ'), ('interpretation', 'NN'), ('natural', 'JJ'), ('language', 'NN'), ('generation', 'NN'), ('processes', 'VBZ'), ('More', 'RBR'), ('recently', 'RB'), ('Description', 'NNP'), ('Logics', 'NNS')], [('We', 'PRP'), ('propose', 'VBP'), ('unified', 'JJ'), ('neural', 'JJ'), ('network', 'NN'), ('architecture', 'NN'), ('learning', 'VBG'), ('algorithm', 'NNS'), ('applied', 'VBN'), ('various', 'JJ'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('tasks', 'NNS'), ('including', 'VBG'), ('part', 'NN'), ('speech', 'NN'), ('tagging', 'VBG'), ('chunking', 'VBG'), ('named', 'VBN'), ('entity', 'NN'), ('recognition', 'NN'), ('semantic', 'JJ'), ('role', 'NN'), ('labeling', 'VBG'), ('This', 'DT'), ('versatility', 'NN'), ('achieved', 'VBD'), ('trying', 'VBG'), ('avoid', 'NN'), ('task', 'NN')], [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'VBG'), ('The', 'DT'), ('subject', 'JJ'), ('Natural', 'NNP'), ('Language', 'NNP'), ('Processing', 'NNP'), ('considered', 'VBN'), ('broad', 'JJ'), ('narrow', 'JJ'), ('senses', 'NNS'), ('In', 'IN'), ('broad', 'JJ'), ('sense', 'NN'), ('covers', 'VBZ'), ('processing', 'VBG'), ('issues', 'NNS'), ('levels', 'NNS'), ('natural', 'JJ'), ('language', 'NN'), ('understanding', 'VBG'), ('including', 'VBG'), ('speech', 'JJ'), ('recognition', 'NN'), ('syntactic', 'JJ'), ('semantic', 'JJ'), ('analysis', 'NN'), ('sentences', 'NNS')], [('Robots', 'NNP'), ('interact', 'NN'), ('humans', 'NNS'), ('face', 'VBP'), ('face', 'NN'), ('using', 'VBG'), ('natural', 'JJ'), ('language', 'NN'), ('need', 'VBP'), ('responsive', 'JJ'), ('way', 'NN'), ('humans', 'NNS'), ('use', 'VBP'), ('language', 'NN'), ('situations', 'NNS'), ('We', 'PRP'), ('propose', 'VBP'), ('psychologicallyinspired', 'JJ'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('system', 'NN'), ('robots', 'NNS'), ('performs', 'VBP'), ('incremental', 'JJ'), ('semantic', 'JJ'), ('interpretation', 'NN'), ('spoken', 'VBN'), ('utterances', 'NNS')], [('Natural', 'JJ'), ('languages', 'NNS'), ('languages', 'VBZ'), ('spoken', 'JJ'), ('humans', 'NNS'), ('Currently', 'RB'), ('yet', 'RB'), ('point', 'NN'), ('languages', 'NNS'), ('unprocessed', 'VBD'), ('forms', 'NNS') ...
# [Counter({'NNP': 1, 'VBD': 1}), Counter({'NN': 9, 'JJ': 9, 'NNS': 3, 'RB': 2, 'VBG': 2, 'VBN': 1, 'PRP': 1, 'VBP': 1}), Counter({'NNS': 4, 'NN': 3, 'NNP': 3, 'JJ': 2, 'NNPS': 2, 'VBD': 2, 'VBG': 1}), Counter({'NN': 8, 'NNS': 4, 'VBZ': 3, 'JJ': 3, 'NNP': 3, 'RB': 2, 'DT': 1, 'PRP': 1, 'CD': 1}), Counter({'NN': 8, 'JJ': 7, 'NNS': 3, 'NNP': 3, 'IN': 1, 'VBD': 1, 'VBN': 1, 'VBZ': 1, 'RBR': 1, 'RB': 1}), Counter({'NN': 12, 'VBG': 6, 'JJ': 5, 'NNS': 2, 'VBN': 2, 'PRP': 1, 'VBP': 1, 'DT': 1, 'VBD': 1}), Counter({'JJ': 9, 'NNP': 4, 'VBG': 4, 'NNS': 4, 'NN': 4, 'DT': 1, 'VBN': 1, 'IN': 1, 'VBZ': 1}), Counter({'NN': 9, 'JJ': 6, 'NNS': 5, 'VBP': 5, 'NNP': 1, 'VBG': 1, 'PRP': 1, 'VBN': 1}), Counter({'NNS': 6, 'NN': 6, 'JJ': 5, 'RB': 2, 'VBZ': 1, 'VBD': 1, 'NNP': 1, 'VBN': 1, 'VBP': 1, 'DT': 1}), Counter({'NNP': 7, 'NN': 7, 'JJ': 3, 'VBD': 2, 'CD': 2, 'NNS': 2, 'VBZ': 1}), Counter({'NN': 10, 'JJ': 7, 'NNP': 4, 'VBG': 2, 'RB': 2, 'NNS': 1, 'VBP': 1, 'VBN': 1}), Counter({'NN': 7, 'NNS': 6, 'JJ': 5, 'RB': 4, 'VBZ': 2, 'VBG': 2, 'VBP': 1, 'DT': 1}), Counter({'NNP': 7, 'NN': 4, 'JJ': 4, 'NNS': 3, 'VBZ': 3, 'VBP': 3, 'VBG': 2, 'JJR': 1, 'IN': 1}), Counter({'NN': 11, 'JJ': 6, 'NNS': 4, 'NNP': 2, 'VBZ': 2, 'PRP': 1, 'VBP': 1, 'VB': 1, 'DT': 1, 'RB': 1}), Counter({'NN': 17, 'JJ': 5, 'VBN': 3, 'NNS': 2, 'VBG': 2, 'VBD': 1, 'DT': 1, 'IN': 1, 'PRP': 1, 'VBP': 1}), Counter({'JJ': 10, 'NN': 6, 'NNS': 5, 'VBD': 2, 'DT': 1, 'VBZ': 1, 'PRP': 1, 'VBP': 1, 'RB': 1, 'CC': 1}), Counter({'NN': 6, 'JJ': 5, 'VBG': 1, 'DT': 1, 'VBN': 1, 'NNS': 1}), Counter({'NN': 8, 'NNP': 4, 'RB': 4, 'JJ': 3, 'NNS': 2, 'VBN': 1, 'IN': 1, 'VB': 1, 'VBD': 1, 'PRP': 1}), Counter({'NN': 9, 'JJ': 5, 'NNP': 5, 'NNS': 4, 'IN': 2, 'VBD': 2, 'TO': 1, 'VB': 1, 'DT': 1}), Counter({'NN': 10, 'JJ': 7, 'NNS': 5, 'DT': 2, 'VBZ': 2, 'NNP': 2, 'VBD': 2, 'VBG': 1}), Counter({'NN': 11, 'JJ': 5, 'NNS': 3, 'VBD': 3, 'DT': 2, 'NNP': 2, 'VBN': 1, 'PRP': 1, 'VBP': 1, 'VBZ': 1, 'VB': 1}), Counter({'NN': 13, 'JJ': 4, 'NNS': 3, 'NNP': 2, 'VBP': 2, 'VBG': 1, 'VBN': 1, 'RB': 1, 'VBZ': 1, 'DT': 1}), Counter({'NN': 10, 'NNP': 6, 'NNS': 5, 'JJ': 2, 'RB': 1, 'IN': 1, 'VBD': 1, 'VBN': 1, 'VBP': 1}), Counter({'NN': 5, 'NNP': 4, 'JJ': 4, 'VBG': 4, 'NNS': 3, 'RB': 2, 'VBD': 1, 'RP': 1, 'CD': 1, 'IN': 1}), Counter({'NN': 10, 'NNS': 4, 'VBZ': 3, 'JJ': 3, 'NNP': 3, 'VBN': 2, 'PRP': 2, 'DT': 1, 'VBP': 1}), Counter({'NN': 10, 'JJ': 4, 'NNP': 4, 'DT': 2, 'NNS': 2, 'VBG': 2, 'VBZ': 1, 'PRP': 1, 'VBP': 1, 'VBN': 1}), Counter({'NN': 10, 'JJ': 5, 'NNS': 3, 'VBG': 2, 'NNP': 2, 'VBZ': 2, 'PRP': 1, 'VBP': 1, 'PRP$': 1, 'VBN': 1, 'WP$': 1}), Counter({'NN': 11, 'JJ': 8, 'NNS': 3, 'DT': 2, 'VBD': 1, 'RB': 1, 'VBG': 1, 'VBZ': 1}), Counter({'NN': 3, 'DT': 2, 'VBN': 2}), Counter({'NN': 10, 'NNP': 6, 'NNS': 4, 'VBG': 2, 'VBP': 2, 'VBD': 1, 'JJ': 1, 'IN': 1}), Counter({'NN': 10, 'JJ': 9, 'NNS': 4, 'VBG': 2, 'VBP': 2, 'NNP': 1, 'MD': 1}), Counter({'NN': 6, 'NNP': 4, 'JJ': 4, 'NNS': 3, 'RB': 2, 'VBG': 2, 'VBD': 1, 'CD': 1}), Counter({'NN': 7, 'JJ': 4, 'NNP': 3, 'VBG': 2, 'NNS': 1, 'VBP': 1, 'RBR': 1}), Counter({'NN': 9, 'JJ': 4, 'NNS': 4, 'NNP': 2, 'DT': 2, 'VBG': 1, 'RB': 1, 'VBD': 1, 'VBP': 1, 'VBN': 1, 'IN': 1}), Counter({'NNP': 1, 'VBD': 1}), Counter({'NN': 8, 'JJ': 5, 'NNS': 3, 'VBG': 3, 'VBP': 3, 'RB': 2, 'CC': 1, 'VBZ': 1, 'PRP': 1, 'VBD': 1, 'VBN': 1}), Counter({'NNP': 1, 'VBD': 1}), Counter({'JJ': 3, 'NNS': 3, 'NN': 3, 'NNP': 3, 'IN': 1, 'VBD': 1, 'VB': 1, 'VBG': 1}), Counter({'NN': 10, 'NNS': 9, 'NNP': 6, 'JJ': 5, 'VBD': 5, 'VBZ': 3, 'DT': 2, 'VBG': 2, 'IN': 2, 'PRP': 1, 'VBP': 1, 'RB': 1}), Counter({'NN': 31, 'JJ': 17, 'NNS': 16, 'VBP': 5, 'NNP': 4, 'IN': 3, 'CD': 3, 'VBZ': 3, 'VBG': 3, 'VBD': 3, 'VBN': 2, 'RB': 2}), Counter({'NN': 32, 'JJ': 21, 'VBN': 10, 'NNS': 8, 'VBG': 7, 'NNP': 6, 'RB': 5, 'VBD': 3, 'IN': 2, 'VBP': 1, 'DT': 1, 'VBZ': 1, 'FW': 1, 'PRP': 1}), Counter({'NNP': 5, 'JJ': 4, 'NNS': 3, 'NN': 2, 'RB': 2, 'VBN': 2, 'VBG': 1, 'MD': 1, 'VB': 1}), Counter({'NNP': 2, 'NN': 1, 'NNS': 1}), Counter({'NNS': 1, 'NNP': 1}), C ...

# %%
pip install benepar
# Out:
# Requirement already satisfied: benepar in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from benepar) (0.29.21)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from benepar) (1.18.5)
# Requirement already satisfied: nltk>=3.2 in /usr/local/lib/python3.6/dist-packages (from benepar) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk>=3.2->benepar) (1.15.0)

# %%
# %tensorflow_version 1.x
import benepar
benepar.download('benepar_en2')
# Out:
# TensorFlow 1.x selected.
# [nltk_data] Downloading package benepar_en2 to /root/nltk_data...
# True

# %%
from benepar.spacy_plugin import BeneparComponent
nlp = spacy.load('en')
nlp.add_pipe(BeneparComponent("benepar_en2"))
for iter in texts:
  doc = nlp(iter)
  sent = list(doc.sents)[0]
  print(sent._.parse_string)
# Out:
# (NP (NP (NN Abstract)) (VBN found))
# (S (VP (VB describe) (NP (NP (NN method) (JJ statistical) (NN modeling)) (VP (VBN based)))))
# (S (S (VP (VBG Scaling) (NP (JJ conditional) (JJ random) (NNS fields)))) (NP (JJ natural) (NN language) (NNP processing) (NNS Terms) (NP (NNS Conditions) (NP (NNS Terms)))))
# (S (NP (DT The) (NN paper)) (VP (VBZ addresses) (NP (NP (NNP issue) (NNP cooperation) (NNP linguistics)) (NP (NNP natural) (NNP language) (NNP processing) (NNP NLP) (NNP general) (NNP linguistics) (NNP machine) (NNP translation) (NNP MT) (NNP particular)))))
# (S (PP (IN In) (NP (JJ natural) (NN language) (VBG processing) (NNS applications))) (NP (NP (NP (NN Description) (NNS Logics)) (VBN used) (VBP encode) (NP (NN knowledge) (NN base) (JJ syntactic) (JJ semantic) (JJ pragmatic) (NNS elements))) (VP (VP (VBN needed) (S (VP (VB drive) (NP (JJ semantic) (NN interpretation))))) (NP (NP (JJ natural) (NN language) (NN generation) (NNS processes)) (ADVP (ADVP (RBR More) (RB recently)) (NP (NN Description) (NNS Logics)))))))
# (S (NP (PRP We)) (VP (VBP propose) (SBAR (S (NP (VBN unified) (NNP neural) (NN network) (NN architecture) (NN learning) (NN algorithm)) (VP (VBD applied) (NP (NP (JJ various) (JJ natural) (NN language) (VBG processing) (NNS tasks)) (PP (VBG including) (NP (NP (NP (NN part) (NN speech) (NN tagging) (NN chunking)) (VBN named) (S (NP (NN entity) (NNP recognition) (NNP semantic) (NNP role)))) (VP (VBG labeling) (NP (NP (DT This) (NN versatility)) (VP (VBD achieved) (S (VP (VBG trying) (VP (VB avoid) (NP (NN task))))))))))))))))
# (NP (JJ Natural) (NNP Language) (NNP Processing))
# (S (NP (NNS Robots)) (VP (VBP interact) (SBAR (S (NP (NNS humans)) (VP (VBP face) (NP (NN face)) (S (VP (VBG using) (NP (JJ natural) (NN language))))))) (VP (MD need) (NP (NP (JJ responsive) (NN way)) (SBAR (S (NP (NNS humans)) (VP (VP (VBP use) (NP (NN language) (NNS situations))) (SBAR (S (NP (PRP We)) (VP (VBP propose)))))))))))
# (NP (NP (NP (JJ Natural) (NNPS languages)) (NNPS languages)) (VBN spoken) (NNS humans) (ADVP (ADVP (RB Currently)) (RB yet)))
# (S (NP (JJ ABSTRACT) (NN Ambiguity)) (VP (VBD referred) (NP (NP (NN ability)) (SBAR (S (NP (CD one) (NN meaning)) (VP (VBD understood) (NP (CD one) (NN way))))))))
# (NP (NP (NNP Introduction)) (NP (NNP Statistical) (NNP natural) (NNP language) (NNP processing) (NP (NNP SNLP) (NN field) (VBG lying))))
# (FRAG (NP (NN text)) (RB directly) (RB rather))
# (S (NP (NP (NNP ABSTRACT) (NN Language) (NN way)) (VP (VBG communicating) (NP (NNS words) (NN Language)))) (VP (VBZ helps) (S (NP (VBG understanding) (NN world)) (VP (VB get) (NP (ADJP (RBR better)) (NN insight) (SBAR (S (NP (NNP world) (NNP Language)) (VP (VBZ helps) (S (NP (NNS speakers)) (VP (JJ vague) (JJ precise) (SBAR (IN like) (S (NP (NNP NLP)) (VP (VBZ Stands) (NP (NP (JJ natural) (NN language)) (VP (VBG processing) (NP (NP (JJ Natural) (NNPS languages) (NNS languages)) (VP (VBN spoken))))))))))))))))))
# (S (NP (PRP We)) (VP (VBP report) (SBAR (S (NP (NNS experiments)) (VP (VBP use) (NP (NP (JJ standard) (JJ natural) (NN language) (NN processing) (NNP NLP) (NNS tools)) (NP (NNP analysis)) (NP (NN music) (NNPS lyrics))) (NP (NP (DT A) (JJ significant) (NN amount)) (NP (NNP music) (NP (NNP audio) (NNPS lyrics) (NNS Lyrics))) (VP (VP (VP (VBP encode) (NP (JJ important) (NN part))) (NNPS semantics)) (NNP song))) (ADVP (RB therefore)) (S (NP (NN analysis)) (VP (VBZ complements) (NP (JJ acoustic) (JJ cultural)))))))))
# (S (NP (NN paper)) (VP (VB describe) (NP (NP (JJ simple) (NN rule) (VBN based) (NN approach)) (VP (VBN automated) (S (VP (VBG learning) (NP (JJ linguistic) (NN knowledge))))))))
# (S (NP (DT This) (NN paper)) (VP (VBZ focuses) (NP (NP (JJ connectionist) (NNS models)) (NP (JJ natural) (NN language) (NN processing)))))
# (S (NP (NP (NN process) (NN language)) (VBG understanding) (NP (DT This) (JJ new) (NN approach))) (NP (NP (JJ natural) (NN language) (NN processing)) (VP (VBD based) (NP (JJ deterministic) (JJ chaotic) (NN behavior) (JJ dynamical) (NNS systems)))))
# (S (NP (NP (NN paper)) (VB see) (NNP Schank) (JJ theoretical) (NN discussion) (NNP Kass) (NNP Leake) (NNP Owens) (JJ brief) (NNS discussions) (NN program)) (VP (VP (VBN built) (PP (IN around) (NP (NNPS principles) (NNP goal)))) (NP (ADVP (RB simply)) (VB point) (NP (NP (NN interest)) (SBAR (S (NP (JJ natural) (NN language) (NN processing)) (VP (VBD led) (NP (PRP us)) (ADVP (ADVP (RB naturally)) (RB indeed)) (RB inevitably))))))))
# (NP (NP (NNS Objectives)) (S (VP (TO To) (VP (VB provide) (NP (NN overview) (JJ tutorial) (JJ natural) (NN language) (VBG processing) (NNP NLP) (NNP modern) (NNP NLP) (NN system) (NN design) (NN Target) (NN audience))))))
# (S (NP (DT This) (NN paper)) (ADVP (RB briefly)) (VP (VBZ describes) (NP (NP (JJ current) (NN implementation) (NN status)) (SBAR (S (JJ intelligent) (NN information) (NN retrieval) (NN system) (SBAR (S (NP (NNP MARIE)) (VP (VBZ employs) (NP (JJ natural) (NN language) (NN processing) (NNS techniques))))))))))
# (NP (NP (VBN based) (NN literature) (NNS resources)) (SBAR (S (NP (PRP We)) (VP (VBP describe)))))
# (S (NP (NN evaluation) (NN speech) (VBG processing) (NN Part)) (VP (VBZ surveys) (NP (NP (JJ significant) (NN evaluation) (NN work)) (VP (VP (VP (VBN done) (ADVP (RB far))) (NP (NN instance))) (S (NP (NN machine) (NNP translation)) (VP (VBZ discusses)))))))
# (NP (JJ similar) (NN way))
# (S (NP (NP (JJ Abstract) (JJ Natural) (NN Language) (NN Processing)) (ADJP (ADVP (RB theoretically)) (VBN motivated)) (NN range) (VBG computational) (NNS techniques)) (VP (VBG analysing) (S (VP (VBG representing) (NP (ADJP (RB naturally) (VBG occurring)) (NNS texts))))) (NP (NP (NP (NP (CD one)) (NNPS levels)) (NP (NNP linguistic) (NN analysis) (NN purpose))) (S (VP (VBG achieving) (NP (NNP human) (IN like) (NP (NN language) (NNP processing) (NNP range) (NNPS tasks)))))))
# (S (NP (DT This) (NN paper)) (VP (VBZ reviews) (NP (NP (NNS processes)) (VP (VP (VBN involved)) (NP (JJ Natural) (NN Language)) (VP (VBG Processing) (NP (NNP NLP)))))))
# (S (NP (DT This) (NN article)) (VP (VBZ focusses) (NP (NP (NN derivation)) (NP (JJ large) (NNS lexicons) (NP (JJ natural) (NN language) (VBG processing))))))
# (S (NP (PRP We)) (VP (VP (VBP introduce) (NP (NP (NN method)) (VP (VBG analyzing) (NP (NP (NN complexity) (JJ natural) (NN language) (VBG processing) (NNS tasks)) (VP (VBG predicting) (NP (NN difficulty) (JJ new) (NNP NLP) (NNPS tasks))))))) (NP (NP (PRP$ Our) (NN complexity)) (VP (VBZ measures) (NP (NNP derived) (NNP Kolmogorov) (NNP complexity) (NNP class) (NNS automata))))))
# (S (VP (VBZ sounds) (NP (NN text) (NN motion))))
# (S (NP (DT This) (NN author)) (VP (VBD produced) (NP (NP (NN version) (NN paper)) (VP (VBD published) (NP (DT The))))))
# (FRAG (NP (NP (NNP Abstract) (JJ Natural) (NN language) (NNP processing) (NNP NLP) (NN application)) (NNP automated) (VBG parsing) (NN machine) (NN learning) (NNS techniques)) (VB analyze) (NP (NP (JJ standard) (NN text) (NNS Applications)) (SBAR (S (NP (NNP NLP) (NNP requirements) (NNP engineering)) (VP (VP (VB include) (NP (NNP extraction) (NNP ontologies))) (NP (NP (NP (NNP requirements)) (NNP specification)) (VP (VB use) (NP (NP (NNP NLP)) (VP (NNP verify) (NP (NN consistency)))))))))))
# (S (NP (NP (JJ statistical) (NN baseline)) (PP (VBG including) (S (VP (VBG forgiving) (NP (NN nature)) (NP (NP (JJ broad) (NN coverage)) (NP (JJ typical) (NN retrieval) (NN task))))))) (VP (VB lack) (NP (NP (JJ good) (NN weighting) (NNS schemes)) (NP (NN compound) (NN index) (NNS terms)))))
# (S (NP (NP (NN Work)) (NP (NNP computational) (NNP linguistics))) (VP (VBD began) (ADVP (RB soon)) (NN development) (NP (NNP first) (NNPS computers) (NNP Booth) (NNP Brandwood) (NNP Cleave)) (RB yet) (VP (VBG intervening) (NP (CD four) (NNS decades)) (JJ pervasive) (NN feeling) (NNP progress) (SBAR (S (NP (NN computer)) (VP (VBG understanding) (NP (JJ natural) (NN language))))))))
# (S (NP (NP (NNP voice) (NNP recognition) (JJ natural) (NN language) (NP (NNP Tamil))) (VP (VBG combining) (NP (NNP digital) (JJ mathematical) (NNP knowledge)) (S (VP (VBG using) (NP (NNP MFCC) (NNP DTW) (NN extract) (NNP match) (NNS features)))))) (VP (VBP improve) (NP (NP (NN accuracy)) (NP (RBR better) (NN performance)))))
# (FRAG (NP (NP (NNP Abstract) (NNP Testing)) (NNP natural) (NNP language) (NNP requirements) (NNP standard) (NNP approach) (NN system) (NNP acceptance) (NNP testing)) (NP (DT This) (NN test)) (ADVP (RB often)) (VP (VBD performed) (NP (NNP independent) (NNP test) (NN organization) (JJ unfamiliar) (NN application) (NN area))))
# (NP (NP (NN Abstract)) (VBN found))
# (NP (NNP conversational) (NNS partners))
# (NP (NP (NN Abstract)) (VBN found))
# (S (PP (IN In) (NP (JJ recent) (NNS years))) (NP (NN machine) (NNP learning) (NNP ML)) (VP (VBD used) (S (VP (S (VP (VB solve) (NP (JJ complex) (NNS tasks)))) (NP (NP (JJ different) (NNS disciplines)) (VP (VBG ranging) (NP (NNP Data) (NNP Mining) (NN Information))))))))
# (S (NP (PRP We)) (VP (VBP argue) (SBAR (S (NP (JJ manual) (JJ automatic) (VBZ thesauruses)) (NP (JJ alternative) (NNS resources) (NP (NNP NLP) (NNS tasks)))))))
# (NP (NP (NNP Introduction) (NNPS Patterns) (NNP music) (NNP object)) (NNP intensive) (NNPS studies) (NP (JJ past) (NNS years)))
# (S (NNP Abstract) (JJ Many) (NNP information) (NNP retrieval) (NNP IR) (NNS systems) (VP (VBP retrieve) (NP (NP (JJ relevant) (NNS documents)) (PP (VBN based) (PP (JJ exact) (VBG matching) (NNS keywords) (NN query) (NNS documents))))))
# (S (NP (NN paper)) (VP (VB argue) (SBAR (S (NP (VBG questionanswering) (NNP QA) (JJ technical) (NNS domains) (ADJP (RB distinctly) (JJ different)) (NNP TREC) (VBN based) (NNP QA) (NN Web) (VBN based) (NNP QA)) (VP (MD can) (RB not) (VP (VB benefit) (NP (NNP lom) (NNP data) (NNP intensive) (NNS approaches))))))))
# (NP (NNP Universit) (FW quot) (FW des) (FW Saarlandes))
# (NP (NNP Proceedings) (NNP Workshop))
# (NP (NNP uni) (NNP hamburg) (NNP de))
# (NP (NP (NN Abstract)) (VBN found))
# (NP (NP (NN Abstract)) (VBN found))
# (S (NP (NNP SRI)) (VP (VBD developed) (NP (JJ new) (NN architecture)) (VBG integrating) (NP (NP (NN speech)) (JJ natural) (NN language) (NN processing)) (VBZ applies) (NP (NP (NP (NNP linguistic) (NNPS constraints)) (NP (NNP recognition))) (VP (ADJP (ADVP (RB incrementally)) (VBG expanding)) (NN state) (NNP transition) (NNP network) (NNP embodied) (NNP unification) (NNP grammar)))))
# (S (NP (DT This) (NN chapter)) (VP (VBZ considers) (S (NP (NN revolution)) (VP (VBN taken) (NP (NN place)) (JJ natural) (NN language) (NN processing) (NN research) (NP (JJ last) (CD five) (NNS years))))))
# (NP (NNP visual) (NNP development) (NNP environment) (NNP support) (NP (JJ visual) (NN assembly) (NN execution) (NN analysis) (NP (NNP modular) (JJ natural) (NN language) (NNP processing) (NNPS systems))))
# (S (PP (IN In) (NP (NP (NN Chapter) (JJ basic)) (VP (VBZ uses) (NP (NN Description) (NNS Logics))))) (NP (JJ Natural) (NN Language) (NN Processing)) (VP (VBD analysed) (ADVP (RB together)) (NP (JJ little) (NN bit) (NN history) (NN role))))
# (S (NP (PRP We)) (VP (VBD applied) (NP (NN structure) (NN learning) (NN model))))
# (NP (NP (NNP mation) (NNP Infrastructure) (NNP digital) (NNP libraries)) (NP (NNP networked) (NNPS services) (NP (NNP digital) (NNP convergence) (NNP intelligent) (NNPS agents))))
# (S (PP (IN Over) (NP (JJ last) (NNS years))) (NP (NP (NNP number) (NNPS areas)) (NP (JJ natural) (NN language) (NN processing))) (VP (VBN begun) (S (VP (VBG applying) (NP (NP (NN graph) (VBN based) (NNS techniques)) (SBAR (S (NP (DT These)) (VP (VBP include) (PP (IN among) (NP (NNS others))) (NP (NN text))))))))))
# (S (PP (IN In) (NP (JJ Natural) (NN Language) (VBG Processing))) (NP (NNP NLP) (NN research)) (VP (VBZ results) (SBAR (S (NP (NN software) (NN engineering) (NN software) (NN technology)) (ADVP (RB often)) (VP (VBN neglected))))))
# (S (NP (JJ kernelized) (NN sorting)) (VP (VP (VBP increase) (NP (NN robustness) (NNP performance))) (NP (NP (JJ several) (JJ Natural) (NN Language) (VBG Processing) (NNP NLP) (NNS tasks)) (VP (VBP document) (S (VP (VBG matching) (NP (JJ parallel) (JJ comparable) (NNP corpora) (NN machine) (NN transliteration))))))))
# (S (VP (VBN structured) (PP (IN In) (NP (NNS words)))))
# (S (PP (IN In) (NP (NN paper))) (VP (VB describe) (NP (NP (NP (NN framework)) (VBG developing) (JJ probabilistic) (NNS classifiers)) (NP (NP (JJ natural) (NN language)) (VP (VBG processing) (NP (PRP$ Our) (NN focus) (VBG formulating) (NNS models))))) (VP (VBP capture) (NP (NP (NP (JJ important) (NNS interdependencies)) (PP (IN among) (NP (NNS features)))) (VP (VB avoid) (S (VP (VBG overfitting) (NP (NNS data)))) (ADVP (RB also)) (VP (VBG characterizing) (NP (NNS data))))))))
# (S (NP (JJ Many) (JJ Natural) (NN Language) (VBG Processing) (NNP NLP) (NNS techniques)) (VP (VBD used) (NP (NN Information) (NN Retrieval))))
# (NP (NN Abstract))
# (S (NP (NP (NNP state) (NNP art) (NNP plan) (NNP recognition) (NNPS systems)) (NP (DT This) (NN paper))) (VP (VBP outline) (NP (NP (NP (PRP relations)) (NP (JJ natural) (NN language) (NNP processing))) (NP (NNP NLP) (NNP plan) (NNP recognition) (NNP PR))) (VP (VBP argue) (ADVP (RB effectively)) (VB inform) (NP (NP (VB focus)) (NP (NP (JJ key) (JJ recent) (NN research) (NNS results)) (SBAR (S (NP (NNP NLP)) (VP (VBP argue) (NP (NN applicability) (NNP PR))))))))))
# (S (NP (NP (NNP state) (NNP art) (NNP plan) (NNP recognition) (NNPS systems)) (NP (DT This) (NN paper))) (VP (VBP outline) (NP (NP (NP (PRP relations)) (NP (JJ natural) (NN language) (NNP processing))) (NP (NNP NLP) (NNP plan) (NNP recognition) (NNP PR))) (VP (VBP argue) (ADVP (RB effectively)) (VB inform) (NP (NP (VB focus)) (NP (NP (JJ key) (JJ recent) (NN research) (NNS results)) (SBAR (S (NP (NNP NLP)) (VP (VBP argue) (NP (NN applicability) (NNP PR))))))))))
# (S (NP (NP (NNP Information) (NNP retrieval) (NN process)) (VP (VBG finding) (NP (NNS documents)) (NN document) (NN collection))) (VP (VBZ satisfies) (NP (NN information) (VB need) (NN user) (NP (NP (DT The) (NNS documents)) (NP (JJ natural) (NN language))))))
# (NP (NP (NNP logic) (NNP programming)) (IN within) (NP (NP (NNP natural) (NN language) (NNP research) (NN machine) (NNP learning) (NNP point)) (NNPS opportunities)) (NP (NP (NNP induction) (NP (NNP linguistic) (NNP knowledge))) (PP (IN within) (NNP logic) (NNP programming) (NNPS Keywords)) (NP (NNP inductive) (NNP logic) (NNP programming) (NNP natural) (NNP language) (NNP processing) (NNP logic) (NP (NP (NNP programming)) (NP (NNP machine)) (NNP learning) (NP (NP (NNP Introduction)) (NP (RB There)))))))
# (S (WHNP (WP What) (JJ statistical) (NN method)) (S (VP (S (VP (VBD used) (NP (JJ natural) (NN language) (VBG processing) (NNP NLP)) (PP (PP (IN In) (NP (NNP paper) (NNP start) (NNP definition))) (NP (NNP NLP))))) (VP (VBD concerned) (NP (NP (NN design) (NN implementation)) (NP (NNP effective) (JJ natural) (NN language) (NN input) (NNP output) (NP (NNPS components) (NP (NP (NNP computational) (NNPS systems)) (SBAR (S (NP (PRP We)) (VP (VBP distinguish) (NP (CD three)))))))))))))
# (S (NP (IN In) (NP (NN report) (JJ collaborative) (NN work) (NNS fields))) (NN Machine) (VBG Learning) (NNP ML) (NNP Natural) (NN Language) (NNP Processing) (NNP NLP) (VP (VBD presented) (NP (NP (DT The) (NN document)) (VP (VBD structured) (NP (CD two) (NNS parts))))))
# (S (ADVP (JJ Abstract)) (NP (DT This) (NN thesis)) (VP (VP (VBZ examines)) (VP (VB use) (NP (NN machine) (NN learning) (NNS techniques)) (NP (JJ various) (NNS tasks) (NP (JJ natural) (NN language) (NNP processing))))))
# (S (NP (DT This) (NN chapter)) (VP (VBZ examines) (NP (NP (NP (NP (NN application)) (JJ natural) (NN language) (NNP processing)) (NP (JJ computerassisted) (NN language) (VBG learning))) (PP (VBG including) (NP (NN history) (NN work) (NN field))) (NP (JJ last) (JJ thirtyfive) (NNS years)) (VP (VB focus) (NP (JJ current) (NNS developments) (NNPS opportunities))))))
# (S (NP (NP (JJ Traditional) (NNS approaches)) (NN tointerpretation) (JJ natural) (NN language) (NN processing)) (ADVP (RB typically)) (VP (VBP fall) (NP (CD one) (CD three) (NNS classes))))
# (NP (NP (NNP Natural) (NNP Language)) (VP (VBG Processing)) (NNP NLP) (ADJP (NNP large) (JJ diverse)) (JJ subtopic) (NNP artificial) (NNP intelligence))
# (NP (NP (JJ Probabilistic) (NNP finite) (NNP state) (NNP string) (NNS transducers)) (NNPS FSTs) (ADJP (RB extremely) (JJ popular)) (JJ natural) (NN language) (VBG processing) (JJ due) (JJ powerful) (JJ generic) (NNS methods) (VBG applying) (S (VP (S (VP (VBG composing) (NP (VBG learning)))) (ADVP (ADVP (RB Unfortunately)) (NNPS FSTs)))) (ADJP (JJ good)) (NNP fit) (NP (JJ much) (JJ current) (NN work) (JJ probabilistic) (NN modeling) (NN machine)))
# (NP (NN ABSTRACT))
# (NP (NP (NN Abstract)) (VBN found))
# (S (NP (NNP Natural) (NNP language) (NNP processing) (NNPS systems) (NNP NLP)) (VP (VBP extract) (NP (JJ clinical) (NN information)) (NP (NP (JJ textual) (NNS reports)) (VP (VBD shown) (NP (NP (JJ effective) (JJ limited) (NNP domains)) (NP (JJ particular) (NNS applications))))) (SBAR (IN Because) (S (NP (NNP NLP) (NNP system)) (ADVP (RB typically)) (VP (VBZ requires) (NP (NP (JJ substantial) (NNS resources)) (SBAR (S (VP (VB develop) (ADJP (JJ beneficial)) (VP (VBN designed) (ADVP (RB easily))))))))))))
# (S (NNPS facts) (NNPS forms) (NNP link) (NNP IE) (NNP recent) (NNP development) (NP (NNP Natural) (NNP Language) (NNP Processing) (NNP logic) (NNP programming) (NNP Prolog)))
# (S (NP (PRP We)) (VP (VBP describe) (NP (NP (JJ single) (JJ convolutional) (JJ neural) (NN network) (NN architecture)) (VBN given) (NP (NP (NN sentence) (VBZ outputs)) (NP (NNP host) (NN language) (VBG processing) (NNPS predictions) (NP (NP (NNP part)) (NNP speech) (NNPS tags) (NP (NNS chunks) (VP (VBN named) (S (NP (NNP entity) (NNPS tags) (NP (NNP semantic) (NNS roles))))))))))))
# (S (NP (PRP We)) (VP (VBD developed) (NP (NNP prototype) (NNP information) (NN retrieval) (NN system)) (VP (VBZ uses) (NP (NP (VBN advanced) (JJ natural) (NN language) (NN processing) (NNS techniques)) (S (VP (VB enhance) (NP (NNP effectiveness)) (NP (JJ traditional) (JJ key) (NN word) (VBN based) (NN document) (NN retrieval))))))))
# (NP (NP (NN Abstract)) (VBN found))
# (FRAG (S (PP (IN In) (NP (NN paper))) (VB discuss) (NP (NP (JJ several) (NNS issues)) (NNS requirements)) (S (VP (VBG enabling) (SBAR (S (NP (JJ natural) (NN language) (VBG processing) (NNS systems)) (VP (VB become) (ADJP (NN context) (JJ adaptive)))))))))
# (S (PP (IN In) (NP (NNP Fall))) (NP (PRP I)) (VP (VBD introduced) (NP (NP (JJ new) (NN course)) (VP (VBN called) (S (NP (NNP Applied) (NNP Natural) (NNP Language) (NNP Processing)))) (NP (NP (NNS students)) (VP (VBP acquire) (S (VP (VBG understanding) (NP (NN text) (NN analysis) (NNS techniques) (NP (ADJP (RB currently) (JJ feasible)) (NP (JJ practical) (NNS applications)))))))))))
# (NP (NP (NN Abstract)) (VBN found))
# (FRAG (NNP Abstract) (JJ Natural) (NN language) (NN processing) (NN study) (JJ mathematical) (NNP computational) (NNP modelling) (NNP various) (NNS aspects) (NP (NNP language) (NNP improvement) (NP (NNP wide) (NNP range) (NNPS systems) (NP (NNP Natural) (NNP language) (NNP language)))) (VP (VBZ arises)) (NP (NP (NNP innate) (NN facility) (NN language) (NP (VBD possessed) (NP (JJ human) (NN intellect)))) (VP (MD may))))
# (S (NP (NP (NNP Natural) (NNP Language) (NNP Processing) (NNP NLP) (NNP branch)) (NP (NNP artificial) (NNP intelligence))) (VP (VP (VBZ includes) (NP (NNP speech) (NNP synthesis) (NN Speech) (NNP recognition) (NN Machine) (NNP translation))) (NP (NP (JJ Natural) (NNP Language)) (S (VP (VBG Processing) (NP (JJ wide) (NNP range) (NNS applications)))))))
# (S (NP (DT An) (NN Evaluation)) (VP (NNP LOLITA) (VP (VBD related) (NP (NP (JJ Natural) (NN Language) (NN Processing) (NNS Systems)) (NP (NNP Paul) (NNP Callaghan))))))
# (S (NP (JJ Previous) (NN work)) (VP (VBD demonstrated) (SBAR (S (NP (NN Web) (NNS counts)) (VP (VBN used) (NP (NP (JJ approximate) (NNP bigram) (NNS counts)) (VP (VBG suggesting))))))))
# (S (NP (DT This) (NN chapter)) (VP (VBZ examines) (NP (NP (NP (NP (NN application)) (JJ natural) (NN language) (NNP processing)) (NP (JJ computerassisted) (NN language) (VBG learning))) (VBG including) (NP (NN history) (NN work) (NN field)) (NP (JJ last) (JJ thirtyfive) (NNS years)) (VB focus) (NP (JJ current) (NNPS developments)) (NNPS opportunities) (NP (NNP Introduction)))))
# (S (NP (DT This) (NN paper)) (VP (VBZ describes) (SBAR (S (NP (JJ natural) (NN language) (NN system)) (VP (VBZ improves) (NP (NP (NN performance) (VBG learning)) (SBAR (S (NP (DT The) (NN system)) (VP (VBZ processes) (NP (JJ short) (JJ English) (NNS narratives)) (ADJP (JJ able) (S (VP (VB acquire) (NP (NP (JJ single) (NN narrative) (JJ new) (NN schema)) (JJ stereotypical) (VP (NN set) (NP (NNS actions)))) (PP (IN During) (S (VP (VBG understanding) (NP (NN process) (NN system) (NNS attempts)))))))))))))))))
# (S (NP (PRP We)) (VP (VBP classify) (NP (NP (NNP review) (JJ current) (NNPS approaches)) (NP (NN software) (NN infrastructure) (NN research) (NN development) (NN delivery) (NNP NLP) (NNPS systems)))))
# (S (NP (NP (NN Confidence) (VBZ measures)) (NP (JJ practical) (NN solution))) (VBG improving) (NP (NN usefulness)) (JJ Natural) (NN Language) (VBG Processing) (NNPS applications) (NN Confidence) (NNP estimation) (JJ generic) (NN machine) (NN learning) (NN approach) (VP (VP (VBG deriving) (NP (NN confidence) (NNS measures))) (SBAR (S (NP (PRP We)) (VP (VBP give) (NP (NN overview) (NN application) (NN confidence) (NN estimation)))))))
# (NP (NNP lex) (NN sign) (NN sense))
# (S (NP (PRP We)) (VP (VBP describe) (NP (NP (NN design) (NN use)) (NP (NNP Stanford)))))
# (S (NP (NNP Gaussian)) (VP (VBZ Processes) (NNP GPs) (JJ powerful) (NNP mod) (VBG elling) (NN framework) (VP (VP (VBG incorporating) (NP (NNPS kernels))) (NP (JJ Bayesian) (NN inference)) (VP (VBD recognised) (NP (NP (NN state) (NN art)) (NP (JJ many) (NN machine) (NN learning) (NNS tasks)))))))
# (NP (NP (NP (DT A) (JJ fundamental) (NNP issue)) (NP (JJ natural) (NN language) (NNP processing))) (JJ prerequisite) (JJ enormous) (NN quantity) (NP (NNP preprogrammed) (NNP knowledge)) (VBG concerning) (NN language) (NN domain) (NN examination) (NN Manual) (NNP acquisition) (NP (NNP knowledge) (NP (NNP tedious) (NNP error))))
# (VP (VBZ supports) (NP (NP (JJ sophisticated) (JJ natural) (NN language) (NN processing)) (ADVP (RB significantly)) (VBG simplifying) (NP (NN interface) (NN domain) (JJ specific) (NN knowledge) (NNP general) (FW linguis) (NNP tic) (NNS resources))))
# (NP (JJ neighboring) (NN map) (NNS nodes))
# (S (NP (DT This) (NN paper)) (VP (VBZ presents) (NP (ADJP (NN workbench) (VBN built)) (NNP Priberam) (NNP Inform) (NNP tica) (NN development) (NNP company) (NNP natural) (NNP language) (NNP processing) (NNP technology))))
# (NP (JJ Abstract) (JJ Natural) (NN Language) (NNP Processing) (NNP NLP) (JJ effective) (NN approach) (VP (VBG bringing) (NP (NP (NN improvement)) (NP (JJ educational) (NN setting)))))
# (NP (NN ABSTRACT))
# (S (NP (NN Text) (NNS statistics)) (VP (ADVP (RB frequently)) (VBD used) (NP (NN stylometry) (NN cryptography) (NNS studies))))
# (S (NP (PRP We)) (VP (VBP summarize) (NP (NP (NN experience)) (S (VP (VBG using) (NP (NNP FrameNet) (CD two) (ADJP (RB rather) (JJ different)) (NNS projects)))))))

# %%
for iter in texts:
  spacy.displacy.render(nlp(iter), style = 'dep', jupyter = True, options={'distance': 150})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f0bd20601f774b939a70d872b73f1b25-0" class="displacy" width="350" height="212.0" direction="ltr" style="max-width: none; height: 212.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Abstract</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">found</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0bd20601f774b939a70d872b73f1b25-0-0" stroke-width="2px" d="M70,77.0 C70,2.0 200.0,2.0 200.0,77.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0bd20601f774b939a70d872b73f1b25-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,79.0 L62,67.0 78,67.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cb497ec34cc2497c8d0b47329d1d59a8-0" class="displacy" width="4250" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">describe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">method</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">statistical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">modeling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">based</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">maximum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">entropy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">present</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">maximum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">likelihood</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">approach</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">automatically</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">constructing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">maximum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">entropy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">models</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">describe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">implement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">approach</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">efficiently</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">examples</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">several</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">problems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb497ec34cc2497c8d0b47329d1d59a8-0-0" stroke-width="2px" d="M220,452.0 C220,302.0 480.0,302.0 480.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb497ec34cc2497c8d0b47329d1d59a8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220,454.0 L212,442.0 228,442.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="dis
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8c52fea32b744f79ab42f80aa163dd3d-0" class="displacy" width="2600" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Scaling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">conditional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">random</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">fields</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Terms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Conditions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Terms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">Conditions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">Copyright</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">works</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">deposited</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Minerva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">Access</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">retained</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c52fea32b744f79ab42f80aa163dd3d-0-0" stroke-width="2px" d="M220,452.0 C220,152.0 790.0,152.0 790.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c52fea32b744f79ab42f80aa163dd3d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220,454.0 L212,442.0 228,442.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c52fea32b744f79ab42f80aa163dd3d-0-1" stroke-width="2px" d="M370,452.0 C370,377.0 475.0,377.0 475.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c52fea32b744f79ab42f80aa163dd3d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,454.0 L362,442.0 378,442.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c52fea32b744f79ab42f80aa163dd3d-0-2" stroke-width="2px" d="M520,452.0 C520,302.0 780.0,302.0 780.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c52fea32b744f79ab42f80aa163dd3d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520,454.0 L512,442.0 528,442.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c52fea32b744f79ab42f80aa163dd3d-0-3" stroke-width="2px" d="M670,452.0 C670,377.0 775.0,377.0 775.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c52fea32b744f79ab42f80aa163dd3d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,454.0 L662,442.0 678,442.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c52fea32b744f79ab42f80aa163dd3d-0-4" stroke-width="2px" d="M70,452.0 C70,77.0 795.0,77.0 795.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c52fea32b744f79ab42f80aa163dd3d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M795.0,454.0 L803.0,442.0 787.0,442.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c52fea32b744f79ab42f80aa163dd3d-0-5" stroke-width="2px" d="M70,452.0 C70,2.0 950.0,2.0 950.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c52fea32b744f79ab42f80aa163dd3d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="12c54feee4354c82af8bb65175e181de-0" class="displacy" width="3950" height="737.0" direction="ltr" style="max-width: none; height: 737.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">paper</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">addresses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">issue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">cooperation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">linguistics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">NLP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">general</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">linguistics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">machine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">translation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">MT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">particular</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">focuses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">direction</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">cooperation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">namely</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">applications</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">linguistics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">NLP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">virtually</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-12c54feee4354c82af8bb65175e181de-0-0" stroke-width="2px" d="M70,602.0 C70,527.0 165.0,527.0 165.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-12c54feee4354c82af8bb65175e181de-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,604.0 L62,592.0 78,592.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-12c54feee4354c82af8bb65175e181de-0-1" stroke-width="2px" d="M220,602.0 C220,527.0 315.0,527.0 315.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-12c54feee4354c82af8bb65175e181de-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220,604.0 L212,592.0 228,592.0" fi
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="976ee2ccd4c14e75b2a19b43ce64bd13-0" class="displacy" width="4100" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">applications</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">Description</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Logics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">used</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">encode</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">knowledge</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">base</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">syntactic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">semantic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">pragmatic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">elements</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">needed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">drive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">semantic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">interpretation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">generation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">processes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">More</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">recently</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">Description</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">Logics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-976ee2ccd4c14e75b2a19b43ce64bd13-0-0" stroke-width="2px" d="M70,527.0 C70,77.0 1095.0,77.0 1095.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-976ee2ccd4c14e75b2a19b43ce64bd13-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,529.0 L62,517.0 78,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-976ee2ccd4c14e75b2a19b43ce64bd13-0-1" stroke-width="2px" d="M220,527.0 C220,452.0 320.0,452.0 320.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#ar
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c2816d15aa534f10b4b630f6ac4a5e58-0" class="displacy" width="4700" height="737.0" direction="ltr" style="max-width: none; height: 737.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">propose</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">unified</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">neural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">network</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">architecture</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">algorithm</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">applied</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">various</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">tasks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">including</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">part</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">speech</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">tagging</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">chunking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">named</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">entity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">recognition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">semantic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">role</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">labeling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">versatility</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">achieved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">trying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">avoid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d6adaca2c5684230944ad9ea463a0a2e-0" class="displacy" width="4400" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">subject</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">Natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">considered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">broad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">narrow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">senses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">broad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">sense</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">covers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">issues</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">levels</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">understanding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">including</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">speech</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">recognition</tspan>
# ...
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Text</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">statistics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">frequently</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">used</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">stylometry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">cryptography</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">studies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">paper</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">text</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">statistics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">tools</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">developed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">ISO</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Prolog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">Details</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">given</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">usage</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">user</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">callable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">predicates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">Logic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">limitations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">program</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">discussed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a28f427de4b641199dfa5b2c292cb1d2-0-0" stroke-width="2px" d="M70,527.0 C70,452.0 170.0,452.0 170.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a28f427de4b641199dfa5b2c292cb1d2-0-0" class="displacy-label" startOffset="50%" sid
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="08cbc75300894065bd02c2a6bbbca439-0" class="displacy" width="3650" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">summarize</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">experience</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">FrameNet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">rather</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">different</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">projects</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">NLP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">conclude</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">NLP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">benefit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">FrameNet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">different</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">ways</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">sketch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">problems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">need</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">overcome</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-08cbc75300894065bd02c2a6bbbca439-0-0" stroke-width="2px" d="M70,452.0 C70,377.0 175.0,377.0 175.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-08cbc75300894065bd02c2a6bbbca439-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,454.0 L62,442.0 78,442.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-08cbc75300894065bd02c2a6bbbca439-0-1" stroke-width="2px" d="M220,452.0 C220,377.0 325.0,377.0 325.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-08cbc75300894065bd02c2a6bbbca439-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M325.0,454.0 L333.0,442.0 317.0,442.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-08cbc75300894065bd02c2a6bbbca439-0-2" stroke-width="2px" d="M370,452.0 C370,377.0 475.0,377.0 475.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-08cbc75300894065bd02c2a6bbbca439-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-ar

# %%
for iter in texts:
  print([(line.text, line.label_) for line in nlp(iter).ents])
# Out:
# []
# []
# [('Minerva Access', 'PERSON')]
# [('NLP', 'ORG'), ('one', 'CARDINAL'), ('NLP', 'ORG')]
# [('Description Logics', 'PERSON')]
# [('algorithm', 'ORG')]
# []
# []
# []
# [('ABSTRACT Ambiguity', 'ORG'), ('one', 'CARDINAL'), ('one', 'CARDINAL')]
# [('Introduction Statistical', 'ORG'), ('SNLP', 'PRODUCT')]
# []
# [('NLP', 'ORG')]
# [('NLP', 'ORG')]
# []
# []
# []
# [('Schank', 'ORG'), ('Kass Leake', 'PERSON')]
# [('NLP', 'ORG'), ('NLP', 'ORG'), ('Target', 'ORG'), ('NLP', 'ORG')]
# [('MARIE', 'ORG'), ('Descriptive', 'ORG')]
# [('NLP', 'ORG'), ('Motivation', 'PERSON')]
# [('NLP', 'ORG')]
# [('Natural Language Processing NLP', 'LAW')]
# [('one', 'CARDINAL')]
# []
# []
# [('NLP', 'ORG'), ('Kolmogorov', 'PERSON')]
# []
# []
# [('NLP', 'ORG'), ('Applications NLP', 'PERSON'), ('NLP', 'ORG')]
# []
# [('Booth Brandwood Cleave', 'GPE'), ('four decades', 'DATE')]
# [('MFCC', 'ORG')]
# []
# []
# [('us', 'GPE')]
# []
# [('recent years', 'DATE'), ('Data Mining Information', 'ORG')]
# [('NLP', 'ORG'), ('NLP', 'ORG'), ('WASPS', 'ORG'), ('Thesaurus', 'ORG'), ('NLP', 'ORG')]
# [('past years', 'DATE'), ('One', 'CARDINAL'), ('Simon Patterns', 'PERSON'), ('One', 'CARDINAL'), ('One', 'CARDINAL')]
# [('Keyfact', 'PERSON'), ('first', 'ORDINAL'), ('second', 'ORDINAL')]
# [('QA', 'ORG'), ('TREC', 'PRODUCT'), ('QA Web', 'PERSON'), ('QA', 'NORP')]
# [('Universit', 'ORG')]
# []
# [('uni', 'ORG'), ('hamburg', 'GPE')]
# []
# []
# []
# [('last five years', 'DATE'), ('two', 'CARDINAL'), ('NLP', 'ORG')]
# []
# [('Chapter', 'ORG'), ('Description Logics', 'PERSON'), ('early days', 'DATE')]
# [('Max Margin Structure', 'PERSON'), ('MMS', 'ORG'), ('NLP', 'ORG'), ('Support Vector Machine SVM', 'ORG')]
# [('NLP', 'ORG')]
# [('last years', 'DATE')]
# []
# []
# []
# []
# []
# [('Malayalam', 'ORG')]
# [('NLP', 'ORG'), ('NLP', 'ORG')]
# [('NLP', 'ORG'), ('NLP', 'ORG')]
# []
# [('Keywords', 'PRODUCT')]
# [('NLP', 'ORG'), ('NLP', 'ORG'), ('three', 'CARDINAL')]
# [('Machine Learning ML Natural Language Processing NLP', 'EVENT'), ('two', 'CARDINAL'), ('first', 'ORDINAL')]
# []
# [('last thirtyfive years', 'DATE')]
# [('one three', 'CARDINAL'), ('Syntax', 'FAC')]
# [('NLP', 'ORG')]
# []
# [('TAL', 'ORG')]
# []
# [('NLP', 'ORG'), ('NLP', 'ORG')]
# [('IE', 'ORG'), ('Natural Language Processing', 'ORG')]
# []
# []
# []
# []
# [('Applied Natural Language Processing', 'ORG')]
# []
# []
# [('Natural Language Processing', 'LAW'), ('Indian', 'NORP'), ('Indian', 'NORP')]
# [('Durham', 'PERSON'), ('August', 'DATE'), ('LOLITA LOLITA Natural', 'ORG')]
# [('Web', 'PERSON'), ('bigram', 'ORG'), ('Web', 'PERSON')]
# [('last thirtyfive years', 'DATE')]
# [('English', 'LANGUAGE')]
# [('NLP', 'ORG')]
# [('Natural Language Processing applications Confidence', 'ORG')]
# [('LKB', 'PERSON'), ('LKB', 'PERSON'), ('LDOCE LLCE', 'WORK_OF_ART'), ('lexicon contain information psychological verbs', 'ORG'), ('Sanfilippo', 'GPE'), ('three', 'CARDINAL'), ('LKB', 'PERSON'), ('MRD', 'ORG'), ('LRL', 'ORG')]
# [('Stanford', 'ORG'), ('NLP', 'ORG'), ('NLP', 'ORG')]
# [('Gaussian Processes', 'ORG')]
# []
# [('linguis tic', 'PERSON'), ('applications past years', 'DATE')]
# [('Nodes', 'GPE')]
# [('Priberam Inform', 'ORG')]
# [('Implementing NLP', 'PERSON')]
# [('twenty years', 'DATE'), ('Sejnowski Rosenberg', 'PERSON')]
# [('ISO Prolog', 'ORG')]
# [('FrameNet', 'ORG'), ('two', 'CARDINAL'), ('NLP', 'ORG'), ('NLP', 'ORG'), ('FrameNet', 'ORG')]

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %%
'''
Constituency Parsing: 
Constituency parsing is breaking a sentence into sub-texts.
Using a set of rules, we try to achieve building valid sentences through constituency parsing.

Dependency Parsing:
Dependency parsing is representing a sentence's grammatical structure.
As opposed to constituency parsing, dependency parsing doesn't make use of sub-phrases.

'''
# Out:
# '\nWrite your explanations of the constituency parsing tree and dependency parsing tree here\n\n\n\n'
